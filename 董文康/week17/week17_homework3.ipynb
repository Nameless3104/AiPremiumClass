# %%
from vllm import LLM, SamplingParams

prompts = [
    "Hello, my name is",
    "The president of the United States is",
    "The capital of France is",
    "The future of AI is",
]

# 初始化
sampling_params = SamplingParams(temperature=0.8, top_p=0.95)
llm = LLM(model="Qwen/Qwen3.5-0.8B", gpu_memory_utilization=0.4)

# 进行推理
outputs = llm.generate(prompts, sampling_params)

# 打印输出
for output in outputs:
    prompt = output.prompt
    generated_text = output.outputs[0].text
    print(f"Prompt: {prompt!r}, Generated text: {generated_text!r}")
# Out:
# INFO 03-31 20:11:44 [utils.py:233] non-default args: {'gpu_memory_utilization': 0.4, 'disable_log_stats': True, 'model': 'Qwen/Qwen3.5-0.8B'}
# INFO 03-31 20:11:45 [model.py:533] Resolved architecture: Qwen3_5ForConditionalGeneration
# INFO 03-31 20:11:45 [model.py:1582] Using max model len 262144
# INFO 03-31 20:11:45 [scheduler.py:231] Chunked prefill is enabled with max_num_batched_tokens=8192.
# INFO 03-31 20:11:45 [config.py:212] Setting attention block size to 544 tokens to ensure that attention page size is >= mamba page size.
# INFO 03-31 20:11:45 [config.py:243] Padding mamba page size by 2.64% to ensure that mamba page size and attention page size are exactly equal.
# (EngineCore pid=75443) INFO 03-31 20:12:00 [core.py:103] Initializing a V1 LLM engine (v0.18.1) with config: model='Qwen/Qwen3.5-0.8B', speculative_config=None, tokenizer='Qwen/Qwen3.5-0.8B', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=262144, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, decode_context_parallel_size=1, dcp_comm_backend=ag_rs, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False), seed=0, served_model_name=Qwen/Qwen3.5-0.8B, enable_prefix_caching=False, enable_chunked_prefill=True, pooler_config=None, compilation_config={'mode': <CompilationMode.VLLM_COMPILE: 3>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['none'], 'splitting_ops': ['vllm::unified_attention', 'vllm::unified_attention_with_output', 'vllm::unified_mla_attention', 'vllm::unified_mla_attention_with_output', 'vllm::mamba_mixer2', 'vllm::mamba_mixer', 'vllm::short_conv', 'vllm::linear_attention', 'vllm::plamo2_mamba_mixer', 'vllm::gdn_attention_core', 'vllm::olmo_hybrid_gdn_full_forward', 'vllm::kda_attention', 'vllm::sparse_attn_indexer', 'vllm::rocm_aiter_sparse_attn_indexer', 'vllm::unified_kv_cache_update', 'vllm::unified_mla_kv_cache_update'], 'compile_mm_encoder': False, 'compile_sizes': [], 'compile_ranges_endpoints': [8192], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.FULL_AND_PIECEWISE: (2, 1)>, 'cudagraph_num_of_warmups': 1, 'cudagraph_capture_sizes': [1, 2, 4, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256, 272, 288, 304, 320, 336, 352, 368, 384, 400, 416, 432, 448, 464, 480, 496, 512], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': False, 'fuse_act_quant': False, 'fuse_attn_quant': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False}, 'max_cudagraph_capture_size': 512, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': True, 'static_all_moe_layers': []}
# (EngineCore pid=75443) WARNING 03-31 20:12:04 [interface.py:525] Using 'pin_memory=False' as WSL is detected. This may slow down the performance.
# (EngineCore pid=75443) INFO 03-31 20:12:07 [parallel_state.py:1395] world_size=1 rank=0 local_rank=0 distributed_init_method=tcp://172.29.114.209:52639 backend=nccl
# (EngineCore pid=75443) INFO 03-31 20:12:07 [parallel_state.py:1717] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# (EngineCore pid=75443) INFO 03-31 20:12:20 [gpu_model_runner.py:4481] Starting to load model Qwen/Qwen3.5-0.8B...
# (EngineCore pid=75443) INFO 03-31 20:12:20 [cuda.py:373] Using backend AttentionBackendEnum.FLASH_ATTN for vit attention
# (EngineCore pid=75443) INFO 03-31 20:12:20 [mm_encoder_attention.py:230] Using AttentionBackendEnum.FLASH_ATTN for MMEncoderAttention.
# (EngineCore pid=75443) INFO 03-31 20:12:20 [qwen3_next.py:198] Using Triton/FLA GDN prefill kernel
# (EngineCore pid=75443) INFO 03-31 20:12:21 [cuda.py:317] Using FLASH_ATTN attention backend out of potential backends: ['FLASH_ATTN', 'FLASHINFER', 'TRITON_ATTN', 'FLEX_ATTENTION'].
# (EngineCore pid=75443) INFO 03-31 20:12:21 [flash_attn.py:598] Using FlashAttention version 2
# (EngineCore pid=75443) INFO 03-31 20:18:29 [weight_utils.py:574] Time spent downloading weights for Qwen/Qwen3.5-0.8B: 362.154615 seconds
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:01<00:00,  1.70s/it]
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:01<00:00,  1.70s/it]
# (EngineCore pid=75443)
# (EngineCore pid=75443) INFO 03-31 20:18:32 [default_loader.py:384] Loading weights took 1.74 seconds
# (EngineCore pid=75443) INFO 03-31 20:18:32 [gpu_model_runner.py:4566] Model loading took 1.72 GiB memory and 367.037617 seconds
# (EngineCore pid=75443) INFO 03-31 20:18:32 [gpu_model_runner.py:5488] Encoder cache will be initialized with a budget of 16384 tokens, and profiled with 1 image items of the maximum feature size.
# (EngineCore pid=75443) INFO 03-31 20:18:41 [backends.py:988] Using cache directory: /home/nameless/.cache/vllm/torch_compile_cache/ec67b38974/rank_0_0/backbone for vLLM's torch.compile
# (EngineCore pid=75443) INFO 03-31 20:18:41 [backends.py:1048] Dynamo bytecode transform time: 4.66 s
# (EngineCore pid=75443) [rank0]:W0331 20:18:43.424000 75443 uv_test/.venv/lib/python3.12/site-packages/torch/_inductor/utils.py:1679] Not enough SMs to use max_autotune_gemm mode
# (EngineCore pid=75443) INFO 03-31 20:18:44 [backends.py:371] Cache the graph of compile range (1, 8192) for later use
# (EngineCore pid=75443) INFO 03-31 20:19:00 [backends.py:387] Compiling a graph for compile range (1, 8192) takes 18.36 s
# (EngineCore pid=75443) INFO 03-31 20:19:01 [decorators.py:627] saved AOT compiled function to /home/nameless/.cache/vllm/torch_compile_cache/torch_aot_compile/d2110bb6a9d4faa122acdba6b190de0c2ccfd24150b2032833f37e257c2f6f8d/rank_0_0/model
# (EngineCore pid=75443) INFO 03-31 20:19:01 [monitor.py:48] torch.compile took 23.78 s in total
# (EngineCore pid=75443) INFO 03-31 20:20:17 [monitor.py:76] Initial profiling/warmup run took 74.63 s
# (EngineCore pid=75443) INFO 03-31 20:20:24 [kv_cache_utils.py:826] Overriding num_gpu_blocks=0 with num_gpu_blocks_override=512
# (EngineCore pid=75443) INFO 03-31 20:20:24 [gpu_model_runner.py:5607] Profiling CUDA graph memory: PIECEWISE=51 (largest=512), FULL=35 (largest=256)
# (EngineCore pid=75443) INFO 03-31 20:20:27 [gpu_model_runner.py:5686] Estimated CUDA graph memory: 2.01 GiB total
# (EngineCore pid=75443) INFO 03-31 20:20:27 [gpu_worker.py:456] Available KV cache memory: 1.69 GiB
# (EngineCore pid=75443) INFO 03-31 20:20:27 [gpu_worker.py:490] In v0.19, CUDA graph memory profiling will be enabled by default (VLLM_MEMORY_PROFILER_ESTIMATE_CUDAGRAPHS=1), which more accurately accounts for CUDA graph memory during KV cache allocation. To try it now, set VLLM_MEMORY_PROFILER_ESTIMATE_CUDAGRAPHS=1 and increase --gpu-memory-utilization from 0.4000 to 0.5678 to maintain the same effective KV cache size.
# (EngineCore pid=75443) INFO 03-31 20:20:27 [kv_cache_utils.py:1316] GPU KV cache size: 36,448 tokens
# (EngineCore pid=75443) INFO 03-31 20:20:27 [kv_cache_utils.py:1321] Maximum concurrency for 262,144 tokens per request: 0.56x
# (EngineCore pid=75443) WARNING 03-31 20:20:27 [compilation.py:1236] Capping cudagraph capture sizes from max 512 to 256 to fit Mamba cache blocks (270 blocks available). This limits the maximum batch size that can use CUDA graphs. To increase this limit, reduce max_num_seqs or increase available GPU memory.
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100%|██████████| 35/35 [00:01<00:00, 25.42it/s]
# Capturing CUDA graphs (decode, FULL): 100%|██████████| 35/35 [00:01<00:00, 20.54it/s]
# (EngineCore pid=75443) INFO 03-31 20:20:31 [gpu_model_runner.py:5746] Graph capturing finished in 4 secs, took 0.34 GiB
# (EngineCore pid=75443) INFO 03-31 20:20:31 [gpu_worker.py:617] CUDA graph pool memory: 0.34 GiB (actual), 2.01 GiB (estimated), difference: 1.67 GiB (492.6%).
# (EngineCore pid=75443) INFO 03-31 20:20:31 [core.py:281] init engine (profile, create kv cache, warmup model) took 118.71 seconds
# (EngineCore pid=75443) INFO 03-31 20:20:31 [vllm.py:775] Asynchronous scheduling is enabled.
# INFO 03-31 20:20:31 [llm.py:391] Supported tasks: ['generate']
# Rendering prompts:   0%|          | 0/4 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/4 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# (EngineCore pid=75443) /home/nameless/codeFolder/uv_test/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: Input tensor shape suggests potential format mismatch: seq_len (5) < num_heads (16). This may indicate the inputs were passed in head-first format [B, H, T, ...] Please verify your input tensor format matches the expected shape [B, T, H, ...].
# (EngineCore pid=75443)   return fn(*args, **kwargs)
# (EngineCore pid=75443) /home/nameless/codeFolder/uv_test/.venv/lib/python3.12/site-packages/vllm/model_executor/layers/fla/ops/utils.py:113: UserWarning: Input tensor shape suggests potential format mismatch: seq_len (5) < num_heads (16). This may indicate the inputs were passed in head-first format [B, H, T, ...] when head_first=False was specified. Please verify your input tensor format matches the expected shape [B, T, H, ...].
# (EngineCore pid=75443)   return fn(*contiguous_args, **contiguous_kwargs)
# (EngineCore pid=75443) /home/nameless/codeFolder/uv_test/.venv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:1181: UserWarning: Input tensor shape suggests potential format mismatch: seq_len (5) < num_heads (16). This may indicate the inputs were passed in head-first format [B, H, T, ...] Please verify your input tensor format matches the expected shape [B, T, H, ...].
# (EngineCore pid=75443)   return fn(*args, **kwargs)
# (EngineCore pid=75443) /home/nameless/codeFolder/uv_test/.venv/lib/python3.12/site-packages/vllm/model_executor/layers/fla/ops/utils.py:113: UserWarning: Input tensor shape suggests potential format mismatch: seq_len (5) < num_heads (16). This may indicate the inputs were passed in head-first format [B, H, T, ...] when head_first=False was specified. Please verify your input tensor format matches the expected shape [B, T, H, ...].
# (EngineCore pid=75443)   return fn(*contiguous_args, **contiguous_kwargs)
# Prompt: 'Hello, my name is', Generated text: ' Alex. I am now serving as a Senior Quality Engineer at GFC in the'
# Prompt: 'The president of the United States is', Generated text: ' required to pay all taxes owed to the United States, including taxes owed to the'
# Prompt: 'The capital of France is', Generated text: '\nA. Paris\nB. Beijing\nC. London\nD. Vienna'
# Prompt: 'The future of AI is', Generated text: ' not just about innovation and efficiency, but about the ability to understand and act on'
